# %%
# %%sh
#
# cd ../proteins_and_models/
# export PATH=$PATH:/usr/local/bin/
# for FILE in *.faa
#     do
#         echo Running carve $FILE
#         carve $FILE
#     done
# Out:
# Running carve Bacillus_sp._bc15.faa
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-25
# Running carve Burkholderia_sp._BT03.faa
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-25
# Running carve Caulobacter_AP07_pacbio_v2.faa
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-25
# Running carve Duganella_sp_CF402.faa
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-25
# Running carve Pantoea_YR343_pacbio_v2.faa
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-25
# Running carve Pseudomonas_GM17_pacbio_v2.faa
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-25
# Running carve Rhizobium_CF142_pacbio_v2.faa
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-06-25
# ...
